# %% [markdown]
# # Informe resultados

# %% [markdown]
# ### **RNN**

# %% [markdown]
# #### **1. Metricas**

# %% [markdown]
# #### **Reporte de Clasificación por Categorías**
# | Categoría   | Precisión | Recall | F1-Score | Soporte |
# |-------------|-----------|--------|----------|---------|
# | Cultura     | 0.89      | 0.90   | 0.89     | 145     |
# | Deportes    | 0.86      | 0.85   | 0.85     | 145     |
# | Economía    | 0.97      | 0.96   | 0.97     | 146     |
# | Justicia    | 0.90      | 0.91   | 0.91     | 145     |
#
# #### **Métricas Generales**
# | Métrica                          | Valor   |
# |----------------------------------|---------|
# | Accuracy promedio (Validación cruzada) | 0.8867 |
# | Accuracy global                  | 0.9053  |
# | Precisión global (ponderada)     | 0.9055  |
# | Recall global (ponderado)        | 0.9053  |
# | F1-score global (ponderado)      | 0.9054  |
#
# #### **Análisis de los Resultados**
#
# **- Desempeño General:** El modelo SimpleRNN logró un **accuracy global** de **0.9053**, lo que demuestra una buena capacidad para clasificar correctamente los datos. Este valor es indicativo de un modelo robusto y confiable en términos generales.
#
# **- Categorías Destacadas:** la categoria **Economía** se destaca con un F1-score de **0.97**, es la categoría más consistente, lo que sugiere que sus características son fácilmente reconocibles por el modelo y la categoria **Deportes** Con un F1-score de **0.85**, es la categoría con menor desempeño, posiblemente por similitudes con otras clases que dificultan su diferenciación.
#
# **- Consistencia del Modelo:** Las métricas globales equilibradas (todas cercanas a 0.91) reflejan que el modelo no favorece ninguna categoría específica, manteniendo un desempeño uniforme en todas las clases.

# %% [markdown]
# #### **2. Matriz de confusión**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### **Analisis Matriz de confusión**
#
# La matriz de confusión muestra un buen desempeño general del modelo, con alta precisión en las clases de **economía** y **justicia** (140 y 132 aciertos). Sin embargo, se observan errores en **deportes**, donde varias instancias se clasificaron incorrectamente como "cultura" o "justicia". Esto indica que el modelo podría mejorar en la diferenciación entre estas categorías cercanas.

# %% [markdown]
# #### **3. Entrenamiento del modelo**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### **Análisis del Entrenamiento**
#
# El gráfico de pérdida muestra una disminución consistente en el **training loss** y el **validation loss**, lo que indica que el modelo aprende efectivamente durante las primeras épocas. Sin embargo, a partir de la época 5, el **validation loss** se estabiliza y muestra ligeras oscilaciones, lo que podría ser un indicio de que el modelo está alcanzando su capacidad máxima de generalización o empezando a sobreajustarse ligeramente.

# %% [markdown]
# ### **LSTM**

# %% [markdown]
# #### **1. Metricas**

# %% [markdown]
# #### **Reporte de Clasificación (LSTM)**
#
# | **Clase**        | **Precisión** | **Recall** | **F1-Score** | **Soporte** |
# |------------------|---------------|------------|--------------|-------------|
# | **Cultura**      | 0.91          | 0.90       | 0.90         | 154         |
# | **Deportes**     | 0.99          | 0.94       | 0.97         | 155         |
# | **Economía**     | 0.88          | 0.95       | 0.91         | 134         |
# | **Justicia**     | 0.96          | 0.96       | 0.96         | 139         |
# | **Exactitud**    |               | **0.93**   |              | **582**     |
# | **Macro Avg**    | 0.93          | 0.94       | 0.93         | 582         |
# | **Weighted Avg** | 0.94          | 0.93       | 0.94         | 582         |
#
# #### **Métricas Adicionales (LSTM)**
#
# | **Métrica**  | **Valor** |
# |--------------|-----------|
# | **Accuracy** | 0.9347    |
# | **Precision**| 0.9363    |
# | **Recall**   | 0.9347    |

# %% [markdown]
# ##### **Análisis de las Métricas**
#
# El modelo LSTM evaluado demuestra un **rendimiento sólido** en la clasificación de las categorías **Cultura**, **Deportes**, **Economía** y **Justicia**:
#
# - **Accuracy:** Con un valor de **93.47%**, el modelo muestra una alta capacidad para realizar predicciones correctas de manera general.
#
# - **Precisión y Recall:** Las métricas de **precisión (93.63%)** y **recall (93.47%)** indican que el modelo equilibra eficazmente la identificación correcta de las clases y la cobertura de todas las instancias relevantes, minimizando tanto los falsos positivos como los falsos negativos.
#
# - **Rendimiento por Clase:** Todas las categorías presentan **F1-scores superiores a 0.90**, lo que resalta la excelente capacidad del modelo para manejar diferentes tipos de datos sin sesgos significativos hacia ninguna clase específica.

# %% [markdown]
# #### **2. Matriz de confusión**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### **Analisis Matriz de confusión**
#
# La matriz de confusión confirma que el modelo LSTM ofrece un **rendimiento robusto** en la mayoría de las categorías, con una **alta precisión general** y una **capacidad efectiva** para clasificar correctamente las instancias. La principal área de mejora reside en diferenciar mejor entre las clases **Cultura** y **Economía**, lo que podría abordarse mediante ajustes en las características del modelo o la incorporación de datos adicionales que ayuden a distinguir estas categorías de manera más clara.
#
# En resumen, el modelo demuestra ser **confiable y eficaz** para la tarea de clasificación, con un desempeño consistente y solo algunas áreas específicas que podrían beneficiarse de optimizaciones adicionales.

# %% [markdown]
# #### **3. Entrenamiento del modelo**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### **Análisis del Entrenamiento**
#
# La gráfica muestra una disminución constante de las pérdidas de entrenamiento y validación durante las primeras épocas, lo que indica que el modelo aprende correctamente. Ambas curvas son similares, sugiriendo que no hay problemas de sobreajuste ni subajuste significativos. Hacia el final, la pérdida de validación muestra un ligero aumento, pero no afecta notablemente el rendimiento general.
#
# En conclusión, el entrenamiento es efectivo y el modelo logra un buen equilibrio entre aprendizaje y generalización, lo que respalda su desempeño sólido en las métricas previamente analizadas.

# %% [markdown]
# #### **4. Evidencia del funcionamiento del modelo**
#
# Se solicto a chat gpt inventar cuatro noticias una por cada etiqueta y poder provar el rendimiento del modelo
#
# Texto: La selección nacional inició esta mañana su preparación para la próxima Copa Continental, que comenzará en dos semanas. Bajo las órdenes del nuevo entrenador, el conjunto ha intensificado las sesiones de entrenamiento, enfocándose en la mejora de la posesión del balón y el fortalecimiento de la defensa. Los aficionados se muestran optimistas, especialmente tras la incorporación de jóvenes promesas provenientes de las ligas menores.
#
# **Etiqueta predicha: deportes**
#
# --------------
#
# Texto: Esta tarde se inaugura en el Museo Central la exposición “Reflejos Urbanos”, una muestra itinerante de arte contemporáneo que reúne obras de más de veinte artistas locales y extranjeros. La exhibición, abierta al público hasta finales de mes, combina pintura, escultura, fotografía y videoinstalaciones, todas ellas inspiradas en la interacción entre el ser humano y el entorno urbano. Se esperan visitas guiadas y charlas con los creadores durante los fines de semana.
#
# **Etiqueta predicha: cultura**
#
# --------------
#
# Texto: La principal bolsa del país cerró la semana con una leve subida del 1,2%, impulsada principalmente por el repunte de las acciones del sector tecnológico y energético. Analistas señalan que, pese a la incertidumbre global, los inversores mantienen la confianza en la solidez de la economía local. Asimismo, el ministerio de Hacienda anunció que continuará con las medidas de incentivos a las pequeñas y medianas empresas, con el fin de fortalecer el crecimiento sostenido.
#
# **Etiqueta predicha: economia**
#
# --------------
#
# Texto: Una magistrada del Juzgado Superior de la capital ordenó hoy la reapertura de un caso que había sido archivado el año pasado, alegando posibles irregularidades en la investigación policial. Según fuentes judiciales, se sospecha que ciertos informes forenses y testimonios clave no fueron debidamente analizados en la fase inicial del proceso. La defensa de la víctima, que llevaba meses exigiendo una revisión independiente, celebra la medida, mientras que las autoridades policiales han prometido colaborar plenamente para esclarecer los hechos. El nuevo juicio se espera que tenga lugar dentro de tres meses.
#
# **Etiqueta predicha: justicia**
#
# --------------
#
# ##### **Conclusión**
#
# Dado los resultado anterior el modelo es capaz de funcionar y etiqueta correctamente nuevos datos

# %% [markdown]
# ### **Comparación entre RNN y LSTM**
#
# | **Aspecto**               | **RNN**                                                                                           | **LSTM**                                                                                          |
# |----------------------------|--------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------|
# | **Accuracy Global**        | 0.9053                                                                                          | 0.9347                                                                                          |
# | **F1-score Ponderado**     | 0.9054                                                                                          | 0.94                                                                                            |
# | **Rendimiento por Categoría** | - Mejor categoría: **Economía** (F1: 0.97).<br>- Peor categoría: **Deportes** (F1: 0.85).            | - Todas las categorías con F1-scores superiores a 0.90.<br>- Mejor categoría: **Deportes** (F1: 0.97). |
# | **Matriz de Confusión**    | - Errores frecuentes en **Deportes**, con confusiones hacia **Cultura** y **Justicia**.          | - Precisión alta en todas las categorías.<br>- Ligeras confusiones entre **Cultura** y **Economía**. |
# | **Curvas de Pérdida**      | - **Training loss** y **validation loss** muestran ligeras oscilaciones desde la época 5.<br>- Posible sobreajuste leve. | - Disminución consistente de pérdidas.<br>- Sin signos de sobreajuste o subajuste. |
# | **Validación Cruzada**     | Requerida para garantizar la robustez del modelo.                                               | No fue necesaria debido a la ausencia de sobreajuste.                                           |
# | **Tiempos de Ejecución**   | Más largos debido a la validación cruzada y características del modelo.                         | Menores tiempos de ejecución, demostrando mayor eficiencia.                                     |
# | **Eficiencia General**     | Menor eficiencia en comparación con LSTM.                                                       | Alta eficiencia en términos de rendimiento y tiempos de entrenamiento.                         |
# | **Conclusión**             | Modelo adecuado, pero con limitaciones en la clasificación de ciertas categorías como **Deportes**. | Modelo superior en métricas, robustez y eficiencia, ideal para la tarea de clasificación analizada. |
